# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from scipy.signal import butter, sosfilt, sosfreqz
import os
import scienceplots

# %%
wav_path = 'input_data/tap_acc.wav'

if not os.path.exists(wav_path):
    raise FileNotFoundError(f"WAV file not found: {wav_path}")

sample_rate, acceleration = wavfile.read(wav_path)
print(f"Loaded '{wav_path}' at {sample_rate} Hz")

wav_path = 'input_data/tap_curr.wav'

if not os.path.exists(wav_path):
    raise FileNotFoundError(f"WAV file not found: {wav_path}")

sample_rate, current = wavfile.read(wav_path)
print(f"Loaded '{wav_path}' at {sample_rate} Hz")

# Normalize if needed
#if data.dtype != np.float32:
#    data = data / np.max(np.abs(data))

# Handle stereo by selecting one channel
# Out:
# Loaded 'input_data/tap_acc.wav' at 44100 Hz
# Loaded 'input_data/tap_curr.wav' at 44100 Hz
# /var/folders/kd/v3035tq94wdfg4dqh988_zcr0000gp/T/ipykernel_89231/1524986431.py:6: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, acceleration = wavfile.read(wav_path)
# /var/folders/kd/v3035tq94wdfg4dqh988_zcr0000gp/T/ipykernel_89231/1524986431.py:14: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, current = wavfile.read(wav_path)

# %%
print("Max sample value:",np.max(current))
print("Min sample val:",np.min(current))
current = [x / ((2.0**31) - 1.0) for x in current] #Convert to normalised floating point
current = [x * 3.0 for x in current] #Convert to current in Amps
current = [x * 1000.0 for x in current] #Convert to current in milliAmps

acceleration = [x / ((2.0**31) - 1.0) for x in acceleration] #Convert to normalised floating point
acceleration = [-x * (1.65 / 0.2228) for x in acceleration] #Convert to acceleration in g
#acceleration = [x * (1.65) for x in acceleration] # convert to V
# Out:
# Max sample value: 106627072
# Min sample val: -326959104

# %%
#set Times New Roman as the default font
import matplotlib as mpl
#mpl.rcParams['font.family'] = 'Times New Roman'

time = np.arange(len(current)) / sample_rate



# Set the time range to zoom in (in seconds)
start_time = 10.57
end_time = 10.72

# Convert to sample indices
start_idx = int(start_time * sample_rate)
end_idx = int(end_time * sample_rate)
range_idx = end_idx - start_idx

#plt.figure(figsize=(6,4))
fig, ax1 = plt.subplots()
lns1 = ax1.plot(time[0:range_idx], current[start_idx:end_idx], label='Current')
ax1.set_xlim(0, end_time-start_time);

plt.xlabel('Time (s)')
plt.ylabel('Current (mA)')
#plt.legend()
#plt.grid(True, color='tab:gray', linestyle='-', linewidth=0.5)



# Get current axis
ax = plt.gca()

ax1.set_ylim([-300,300])
y_min, y_max = ax1.get_ylim()

#ax.set_ylim([-180,180])
#ax.set_xlim([0,0.07])

ax2 = ax1.twinx()
lns2 = ax2.plot(time[0:range_idx], acceleration[start_idx:end_idx], label='Acceleration', color='red')
ax2.set_ylim([-8,8])
ax2.set_ylabel("Acceleration (g)")

#plt.grid(True, which='major',axis='both', linestyle='--', linewidth=0.5)

lns = lns1+lns2
labs = [l.get_label() for l in lns]
ax.legend(lns, labs)

plt.style.use(['science','ieee'])

#f_size = list(plt.rcParams["figure.figsize"])
#f_size[1] = f_size[1] / 1.5
#plt.rcParams["figure.figsize"] = tuple(f_size)

#plt.tight_layout()
plt.savefig('outputs/current_tap.eps', format='eps')
plt.show()
